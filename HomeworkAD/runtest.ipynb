# %%
LabAD = joinpath(dirname(@__DIR__), "LabAD")

include(joinpath(LabAD, "test", "test.jl"))

# Reference implementation we test against
include(joinpath(LabAD, "solution", "forward.jl"))


## First order
include(joinpath(@__DIR__, "reverse_vectorized.jl"))
# Out:
# LoadError: ArgumentError: Package Maing not found in current path.
#
# - Run `import Pkg; Pkg.add("Maing")` to install the Maing package.
#
# in expression starting at c:\Users\jdepo\Documents\Ma1\algorithms-for-data-science\LINMA2472\HomeworkAD\reverse_vectorized.jl:3
#
#
#
# Stacktrace:
#
#  [1] macro expansion
#
#    @ .\loading.jl:2375 [inlined]
#
#  [2] macro expansion
#
#    @ .\lock.jl:376 [inlined]
#
#  [3] __require(into::Module, mod::Symbol)
#
#    @ Base .\loading.jl:2358
#
#  [4] require(into::Module, mod::Symbol)
#
#    @ Base .\loading.jl:2334
#
#  [5] top-level scope
#
#    @ c:\Users\jdepo\Documents\Ma1\algorithms-for-data-science\LINMA2472\HomeworkAD\reverse_vectorized.jl:5

# %%
run_gradient_tests(Forward.gradient, VectReverse.gradient)
# Out:
# Test Summary: | Pass  Total   Time
# Identity      |   30     30  10.8s
# Test Summary:                  | Pass  Total  Time
# Identity with identical labels |    5      5  0.1s
# Test Summary:               | Pass  Total  Time
# Identity with small numbers |    5      5  0.1s
# Test Summary:             | Pass  Total  Time
# Identity with big numbers |    5      5  0.1s
# Test Summary:                 | Pass  Total  Time
# Identity with extreme numbers |    5      5  0.1s
# Test Summary:            | Pass  Total  Time
# Identity with big matrix |    5      5  0.6s
# Test Summary:                | Pass  Total  Time
# Identity with sparse weights |    5      5  0.8s
# Test Summary:             | Pass  Total  Time
# Identity with zero matrix |   20     20  0.4s
# Test Summary: | Pass  Total  Time
# Tanh          |   30     30  4.7s
# Test Summary:              | Pass  Total  Time
# Tanh with identical labels |    5      5  0.3s
# Test Summary:           | Pass  Total  Time
# Tanh with small numbers |    5      5  0.3s
# Test Summary:         | Pass  Total  Time
# Tanh with big numbers |    5      5  0.3s
# Test Summary:             | Pass  Total  Time
# Tanh with extreme numbers |    5      5  0.3s
# Test Summary:        | Pass  Total   Time
# Tanh with big matrix |    5      5  10.5s
# Test Summary:            | Pass  Total  Time
# Tanh with sparse weights |    5      5  0.3s
# Test Summary:         | Pass  Total  Time
# Tanh with zero matrix |   20     20  1.7s
# Test Summary: | Pass  Total  Time
# ReLU          |   30     30  5.7s
# Test Summary:              | Pass  Total  Time
# ReLU with identical labels |    5      5  0.3s
# Test Summary:           | Pass  Total  Time
# ReLU with small numbers |    5      5  0.3s
# Test Summary:         | Pass  Total  Time
# ReLU with big numbers |    5      5  0.3s
# Test Summary:             | Pass  Total  Time
# ReLU with extreme numbers |    5      5  0.3s
# Test Summary:        | Pass  Total   Time
# ReLU with big matrix |    5      5  10.0s
# Test Summary:            | Broken  Total  Time
# ReLU with sparse weights |      5      5  0.3s
# Test Summary:         | Broken  Total  Time
# ReLU with zero matrix |     20     20  1.7s
# Test Summary: | Pass  Total   Time
# Softmax       |   30     30  26.2s
# Test Summary:                 | Pass  Total  Time
# Softmax with identical labels |    5      5  8.6s
# Test Summary:              | Pass  Total  Time
# Softmax with small numbers |    5      5  9.5s
# Test Summary:           | Pass  Total  Time
# Softmax with big matrix |    5      5  9.9s
# Test Summary:               | Broken  Total  Time
# Softmax with sparse weights |      5      5  8.9s
# Test Summary:            | Broken  Total   Time
# Softmax with zero matrix |     20     20  19.8s

# %%
LabAD = joinpath(dirname(@__DIR__), "LabAD")

include(joinpath(LabAD, "test", "test.jl"))

# Reference implementation we test against
include(joinpath(LabAD, "solution", "forward.jl"))


## First order
include(joinpath(@__DIR__, "reverse_vectorized.jl"))

run_gradient_tests(Forward.hessian, VectReverse.hessian, hessian = true)
# Out:
# Identity: Error During Test at c:\Users\jdepo\Documents\Ma1\algorithms-for-data-science\LINMA2472\LabAD\test\test.jl:77
#   Got exception outside of a @test
#   MethodError: no method matching ndims(::Type{Main.VectReverse.VectNode})
#   The function `ndims` exists, but no method is defined for this combination of argument types.
#
#   Closest candidates are:
#     ndims(::Type{Union{}}, Any...)
#      @ Base abstractarray.jl:276
#     ndims(::Type{<:Ref})
#      @ Base refpointer.jl:104
#     ndims(::Type{<:AbstractChar})
#      @ Base char.jl:206
#     ...
#
#   Stacktrace:
#     [1] Base.Broadcast.BroadcastStyle(::Type{Main.VectReverse.VectNode})
#       @ Base.Broadcast .\broadcast.jl:103
#     [2] combine_styles(c::Main.VectReverse.VectNode)
#       @ Base.Broadcast .\broadcast.jl:433
#     [3] combine_styles(c1::Main.VectReverse.VectNode, c2::Base.Broadcast.Broadcasted{Base.Broadcast.DefaultArrayStyle{2}, Nothing, typeof(identity), Tuple{Matrix{Float64}}})
#       @ Base.Broadcast .\broadcast.jl:438
#     [4] materialize!(dest::Main.VectReverse.VectNode, bc::Base.Broadcast.Broadcasted{Base.Broadcast.DefaultArrayStyle{2}, Nothing, typeof(identity), Tuple{Matrix{Float64}}})
#       @ Base.Broadcast .\broadcast.jl:902
#     [5] gradient!(f::var"#loss##38#loss##39"{typeof(mse), typeof(identity_activation), Matrix{Float64}, Vector{Float64}}, g::Flatten{Main.VectReverse.VectNode}, x_nodes::Flatten{Main.VectReverse.VectNode})
#       @ Main.VectReverse c:\Users\jdepo\Documents\Ma1\algorithms-for-data-science\LINMA2472\HomeworkAD\reverse_vectorized.jl:394
#     [6] gradient(f::Function, x::Flatten{Main.VectReverse.VectNode})
#       @ Main.VectReverse c:\Users\jdepo\Documents\Ma1\algorithms-for-data-science\LINMA2472\HomeworkAD\reverse_vectorized.jl:399
#     [7] #hessian##0
#       @ c:\Users\jdepo\Documents\Ma1\algorithms-for-data-science\LINMA2472\HomeworkAD\reverse_vectorized.jl:451 [inlined]
#     [8] pushforward(f::Main.VectReverse.var"#hessian##0#hessian##1"{var"#loss##38#loss##39"{typeof(mse), typeof(identity_activation), Matrix{Float64}, Vector{Float64}}}, x::Flatten{Main.VectReverse.VectNode}, tx::Vector{Float64})
#       @ Main.VectReverse c:\Users\jdepo\Documents\Ma1\algorithms-for-data-science\LINMA2472\HomeworkAD\reverse_vectorized.jl:408
#     [9] jacobian(f::Function, x::Flatten{Main.VectReverse.VectNode}, i::Int64)
#       @ Main.VectReverse c:\Users\jdepo\Documents\Ma1\algorithms-for-data-science\LINMA2472\HomeworkAD\reverse_vectorized.jl:432
#    [10] #jacobian##2
#       @ .\none:-1 [inlined]
#    [11] iterate
#       @ .\generator.jl:48 [inlined]
#    [12] collect(itr::Base.Generator{UnitRange{Int64}, Main.VectReverse.var"#jacobian##2#jacobian##3"{Main.VectReverse.var"#hessian##0#hessian##1"{var"#loss##38#loss##39"{typeof(mse), typeof(identity_activation), Matrix{Float64}, Vector{Float64}}}, Flatten{Main.VectReverse.VectNode}}})
#       @ Base .\array.jl:790
#    [13] jacobian(f::Function, x::Flatten{Main.VectReverse.VectNode})
#       @ Main.VectReverse c:\Users\jdepo\Documents\Ma1\algorithms-for-data-science\LINMA2472\HomeworkAD\reverse_vectorized.jl:441
#    [14] hessian(f::Function, x::Flatten{VecOrMat{Float64}})
#       @ Main.VectReverse c:\Users\jdepo\Documents\Ma1\algorithms-for-data-science\LINMA2472\HomeworkAD\reverse_vectorized.jl:451
#    [15] check_case(X::Matrix{Float64}, y::Vector{Float64}, w::Flatten{VecOrMat{Float64}}, loss_function::Function, activation::Function, Reference_diff::typeof(Main.Forward.hessian), Given_diff::typeof(Main.VectReverse.hessian), rtol::Float64, test::Bool)
#       @ Main c:\Users\jdepo\Documents\Ma1\algorithms-for-data-science\LINMA2472\LabAD\test\test.jl:25
#    [16] check_case(X::Matrix{Float64}, y::Vector{Float64}, w::Flatten{VecOrMat{Float64}}, loss_function::Function, activation::Function, Reference_diff::Function, Given_diff::Function, rtol::Float64)
#       @ Main c:\Users\jdepo\Documents\Ma1\algorithms-for-data-science\LINMA2472\LabAD\test\test.jl:23
#    [17] macro expansion
#       @ c:\Users\jdepo\Documents\Ma1\algorithms-for-data-science\LINMA2472\LabAD\test\test.jl:85 [inlined]
#    [18] macro expansion
#       @ C:\Users\jdepo\.julia\juliaup\julia-1.12.0+0.x64.w64.mingw32\share\julia\stdlib\v1.12\Test\src\Test.jl:1776 [inlined]
#    [19] run_gradient_tests(Reference_diff::Function, Given_diff::typeof(Main.VectReverse.hessian), loss_function::typeof(mse), activation::typeof(identity_activation); name::String, classification::Bool, num_repeats::Int64, rtol::Float64, hessian::Bool, zero_test::Bool)
#       @ Main c:\Users\jdepo\Documents\Ma1\algorithms-for-data-science\LINMA2472\LabAD\test\test.jl:79
#    [20] #run_gradient_tests#569
#       @ c:\Users\jdepo\Documents\Ma1\algorithms-for-data-science\LINMA2472\LabAD\test\test.jl:215 [inlined]
#    [21] run_gradient_tests
#       @ c:\Users\jdepo\Documents\Ma1\algorithms-for-data-science\LINMA2472\LabAD\test\test.jl:213 [inlined]
#    [22] top-level scope
#       @ c:\Users\jdepo\Documents\Ma1\algorithms-for-data-science\LINMA2472\HomeworkAD\jl_notebook_cell_df34fa98e69747e1a8f8a730347b8e2f_W2sZmlsZQ==.jl:12
#    [23] eval(m::Module, e::Any)
#       @ Core .\boot.jl:489
#    [24] include_string(mapexpr::typeof(REPL.softscope), mod::Module, code::String, filename::String)
#       @ Base .\loading.jl:2843
#    [25] (::VSCodeServer.var"#notebook_runcell_request##0#notebook_runcell_request##1"{VSCodeServer.NotebookRunCellArguments, String})()
#       @ VSCodeServer c:\Users\jdepo\.vscode\extensions\julialang.language-julia-1.149.2\scripts\packages\VSCodeServer\src\serve_notebook.jl:24
#    [26] withpath(f::VSCodeServer.var"#notebook_runcell_request##0#notebook_runcell_request##1"{VSCodeServer.NotebookRunCellArguments, String}, path::String)
#       @ VSCodeServer c:\Users\jdepo\.vscode\extensions\julialang.language-julia-1.149.2\scripts\packages\VSCodeServer\src\repl.jl:276
#    [27] notebook_runcell_request(conn::VSCodeServer.JSONRPC.JSONRPCEndpoint{Base.PipeEndpoint, Base.PipeEndpoint, VSCodeServer.JSON.Serializations.StandardSerialization}, params::VSCodeServer.NotebookRunCellArguments, token::VSCodeServer.CancellationTokens.CancellationToken)
#       @ VSCodeServer c:\Users\jdepo\.vscode\extensions\julialang.language-julia-1.149.2\scripts\packages\VSCodeServer\src\serve_notebook.jl:13
#    [28] dispatch_msg(x::VSCodeServer.JSONRPC.JSONRPCEndpoint{Base.PipeEndpoint, Base.PipeEndpoint, VSCodeServer.JSON.Serializations.StandardSerialization}, dispatcher::VSCodeServer.JSONRPC.MsgDispatcher, msg::VSCodeServer.JSONRPC.Request)
#       @ VSCodeServer.JSONRPC c:\Users\jdepo\.vscode\extensions\julialang.language-julia-1.149.2\scripts\packages\JSONRPC\src\typed.jl:68
#    [29] serve_notebook(pipename::String, debugger_pipename::String, outputchannel_logger::Base.CoreLogging.SimpleLogger; error_handler::var"#14#15"{String})
#       @ VSCodeServer c:\Users\jdepo\.vscode\extensions\julialang.language-julia-1.149.2\scripts\packages\VSCodeServer\src\serve_notebook.jl:147
#    [30] top-level scope
#       @ c:\Users\jdepo\.vscode\extensions\julialang.language-julia-1.149.2\scripts\notebook\notebook.jl:35
#    [31] include(mod::Module, _path::String)
#       @ Base .\Base.jl:306
#    [32] exec_options(opts::Base.JLOptions)
#       @ Base .\client.jl:317
#    [33] _start()
#       @ Base .\client.jl:550
# Test Summary: | Error  Total  Time
# Identity      |     1      1  9.0s
# RNG of the outermost testset: Random.Xoshiro(0xf4b53a56ba0f1ab3, 0x814d8d0da3e938c7, 0xa0690fea9b80d15b, 0x573519b68d9d5f90, 0xfd1ee5128e9c78bf)
# Some tests did not pass: 0 passed, 0 failed, 1 errored, 0 broken.
#
#
#
# Stacktrace:
#
#  [1] finish(ts::Test.DefaultTestSet; print_results::Bool)
#
#    @ Test C:\Users\jdepo\.julia\juliaup\julia-1.12.0+0.x64.w64.mingw32\share\julia\stdlib\v1.12\Test\src\Test.jl:1270
#
#  [2] finish
#
#    @ C:\Users\jdepo\.julia\juliaup\julia-1.12.0+0.x64.w64.mingw32\share\julia\stdlib\v1.12\Test\src\Test.jl:1245 [inlined]
#
#  [3] macro expansion
#
#    @ C:\Users\jdepo\.julia\juliaup\julia-1.12.0+0.x64.w64.mingw32\share\julia\stdlib\v1.12\Test\src\Test.jl:1792 [inlined]
#
#  [4] run_gradient_tests(Reference_diff::Function, Given_diff::typeof(Main.VectReverse.hessian), loss_function::typeof(mse), activation::typeof(identity_activation); name::String, classification::Bool, num_repeats::Int64, rtol::Float64, hessian::Bool, zero_test::Bool)
#
#    @ Main c:\Users\jdepo\Documents\Ma1\algorithms-for-data-science\LINMA2472\LabAD\test\test.jl:79
#
#  [5] #run_gradient_tests#569
#
#    @ c:\Users\jdepo\Documents\Ma1\algorithms-for-data-science\LINMA2472\LabAD\test\test.jl:215 [inlined]
#
#  [6] run_gradient_tests
#
#    @ c:\Users\jdepo\Documents\Ma1\algorithms-for-data-science\LINMA2472\LabAD\test\test.jl:213 [inlined]
#
#  [7] top-level scope
#
#    @ c:\Users\jdepo\Documents\Ma1\algorithms-for-data-science\LINMA2472\HomeworkAD\jl_notebook_cell_df34fa98e69747e1a8f8a730347b8e2f_W2sZmlsZQ==.jl:12
